# %% [markdown]
# <a id='top'></a>
#
# # CSCI3022 S21
# # Homework 5: Testing and Confidence
# ***
#
# **Name**: Ara Anner
#
# ***
#
# This assignment is due on Canvas by **MIDNIGHT on Friday, April 8**. Your solutions to theoretical questions should be done in Markdown directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Any relevant data sets should be available on Canvas. To make life easier on the graders if they need to run your code, do not change the relative path names here. Instead, move the files around on your computer.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Here is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Canvas on writing math in Markdown. **All** of your written commentary, justifications and mathematical work should be in Markdown.  I also recommend the [wikibook](https://en.wikibooks.org/wiki/LaTeX) for LaTex.
# - Because you can technically evaluate notebook cells is a non-linear order, it's a good idea to do **Kernel $\rightarrow$ Restart & Run All** as a check before submitting your solutions.  That way if we need to run your code you will know that it will work as expected.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.
# - 95 points of this assignment are in problems.  The remaining 5 are for neatness, style, and overall exposition of both code and text.
# - This probably goes without saying, but... For any question that asks you to calculate something, you **must show all work and justify your answers to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
#
# ---
# **Shortcuts:**  [Problem 1](#p1) | [Problem 2](#p2) | [Problem 3](#p3) |
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# <br>
#
# ---
# <a/ id='p1'></a>
# [Back to top](#top)
# ## [15 points] Problem 1 - Time and Testing
#
# The flowers bloomed early this year in Kyoto, Japan (see: [Washington Post](https://www.washingtonpost.com/weather/2021/03/29/japan-kyoto-cherry-blossoms-record/))  Does this mean anything?

# %% [markdown]
# **Part A**: Load in the data set in `kyotoflowers.csv`, a UTF-8 encoded CSV file.  The file contains two columns (with a header).
#
# - `AD`. : Year in Gregorian calendar (Year)
# - `Full-flowering date (DOY)` : Full-flowering date in Gregorian calendar (FuFD)
#
# Citations:
# Full-flowering Dates of Prunus jamasakura in Kyoto City (Plain Text Version)
# (for 9th to 14th centuries: Aono and Saito, 2010; Int. J. Biometeorol.,54, 211-219)
# (for 15th to 21st centuries: Aono and Kazui, 2008; Int. J. Climatol., 28, 905-914)
#
# Begin with a **Histogram** of the data.  Label axes and choose an appropriate number of bins.  Does this data appear to be approximately normally distributed?

# %%
df=pd.read_csv('kyotoflowers.csv', encoding='UTF-8') # !!!!!!!!!!! MODIFIED THE FILEPATH

plt.hist(df["Full-flowering date (DOY)"], bins = 20)

plt.xlabel('Full-Flowering Date (DOY)')
plt.ylabel('# of Years')

plt.show()

# Pretty normally distributed.

# %% [markdown]
# **Part B**:Create a line plot where `Year` is the horizontal axis and `FuFD`is the vertical axis.  Do there *visually* appear to be any patterns?

# %%
plt.plot(df["AD"], df["Full-flowering date (DOY)"])

plt.show()

# Visually, most of the FUFDs seem to be around 100-110, although there's a recent decline in them.

# %% [markdown]
# **Part C**: Print out a Tukey five-number summary for the set of full-flowering dates, as well as its mean and standard deviation.

# %%
print("Tukey Five Number Summary-\n")

print("Minimum: " + str(df["Full-flowering date (DOY)"].min()) + "\n")

print("Lower Quartile: " + str(df["Full-flowering date (DOY)"].quantile(0.25)) + "\n")

print("Median: " + str(df["Full-flowering date (DOY)"].median()) + "\n")

print("Upper Quartile: " + str(df["Full-flowering date (DOY)"].quantile(0.75)) + "\n")

print("Max: " + str(df["Full-flowering date (DOY)"].max()) + "\n")

print("Other Stuff-\n")

print("Mean: " + str(df["Full-flowering date (DOY)"].mean()) + "\n")

print("Standard Deviation: " + str(df["Full-flowering date (DOY)"].std()) + "\n")
# Out:
# Tukey Five Number Summary-
#
# Minimum: 85.0
#
# Lower Quartile: 100.0
#
# Median: 104.0
#
# Upper Quartile: 109.0
#
# Max: 124.0
#
# Other Stuff-
#
# Mean: 104.45378151260505
#
# Standard Deviation: 6.476146188669122

# %% [markdown]
# **Part D**: Suppose we wish to approach the question: is the flowering date becoming *earlier*?  One way to do this might be to generate confidence intervals comparing e.g. the last $n$ years of data to all the years that came before them and ask if they're coming from distributions with the same *means*.
#
# Suppose we take the most recent 12 years of take, from 2010-2021.  What is the mean full-flowering date for those years?  Perform a hypothesis test at $\alpha=0.01$ testing whether or not the mean from this interval is the same as the mean for the prior all-observed years.
#
# Write a sentence interpreting this result.
#
# **Note:** there are a lot of missing observations, especially for centuries ago. Make sure you're properly not including these in any variance/confidence/etc. calculations.

# %%
twelve_df = df.loc[(df["AD"] >= 2010) & (df["AD"] <= 2021)]

alpha = stats.norm.ppf(0.99)

twelve_mean = twelve_df["Full-flowering date (DOY)"].mean()


old_mean = (df.dropna(subset=['AD', 'Full-flowering date (DOY)']))["Full-flowering date (DOY)"].mean()

old_std = (df.dropna(subset=['AD', 'Full-flowering date (DOY)']))["Full-flowering date (DOY)"].std()

result = (twelve_mean - old_mean) / (old_std / np.sqrt(12))

print("-za = " + str(-alpha))
print("z = " + str(result))
# Out:
# -za = -2.3263478740408408
# z = -5.50259523407176

# %% [raw]
# Since -5.5 < -2.33, we reject the null hypothesis, and conclude that there is sufficient evidence to believe at the 1% significance level, that the mean DOY of years 2010-2021 is less than that of the DOY since the beginning of the record.

# %% [markdown]
# **Part E**: Was the test in part D appropriate to answer a broad question like "does the full flowering data reflect the presence of global warming?"  What tests could we have run instead?

# %% [raw]
# Somewhat. The mean has gone down, which does show that there may be some change, we should at least demonstrate error rates to see how solid the hypothesis is to begin with.

# %% [markdown]
# **Part F**: We should have rejected the null hypothesis in Part D.  But sometimes, people do some shifty things with data.  And we could, too!  One way to be statistically disingenuous is known as $p$-fishing or $p$-hacking.  This process represent the idea of "cherry-picking" through our data to find *subsets* of the data that most support a desired conclusion.
#
# Suppose we - for whatever reason - really wish to use this data set to come to the conclusion that "there is no difference in full flowering datas between now and the past."  To support this conclusion, we devise the following idea:
#
# - Consider *every single* list of 12 consecutive years in the data set, starting with 1600-1611, then 1601-1612, then 1602-1613.
# - For *each* one of those 12-year intervals, generate the 99% confidence interval for the difference in the mean `FuFD`  over  those 12 years' to the mean from most recent 12 years from 2010-2021.
#
# From that list of confidence intervals, print out a list of every starting year for an interval that contains zero. (e.g if the confidence interval for comparing 1618-1629 to 2010-2021 contains zero, then print `1618`.  Report:
# - The earliest date of such an interval contianing zero.
# - The latest date where such an interval **does not** contain zero.
#
# Then write two sentences of how you could interpret those two results to conclude *either* that the flowering dates are getting earlier **or** that they are not getting earlier.

# %%
year = 1600

earliest_zero = []
latest_zero = []

while year < 2010:
    
    new_df = df.loc[(df["AD"] >= year) & (df["AD"] <= (year + 11))]
    new_mean = new_df["Full-flowering date (DOY)"].mean()
    
    mean_diff = new_mean - twelve_mean
    
    std_diff = 2.576 * (np.sqrt(pow(new_df["Full-flowering date (DOY)"].std(), 2)/12 + pow(twelve_df["Full-flowering date (DOY)"].std(), 2)/12))
    
    int_end_1 = mean_diff - std_diff
    int_end_2 = mean_diff + std_diff
    
    if int_end_1 > 0 and int_end_2 < 0:
        print(year)
        earliest_zero.append(year)
    elif int_end_2 > 0 and int_end_1 < 0:
        print(year)
        earliest_zero.append(year)
    else:
        latest_zero.append(year)
    
    year += 1

print("Earliest date of an interval containing 0: " + str(earliest_zero[0]))
print("Latest date of an interval containing no 0: " + str(latest_zero[len(latest_zero) - 1]))
# Out:
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# Earliest date of an interval containing 0: 1979
# Latest date of an interval containing no 0: 1978

# %% [raw]
# Getting Earlier--
#
# Because we can see that from 1979, the intervals contain 0, this means the mean difference (of the means) is growing closer and closer to 0, meaning that the values are getting closer to the mean value from 2010-2021, which we know from earlier is smaller than the overall interval mean.
#
# Not Getting Earlier--
#
# We're comparing the means to that of the 2010-2021 one, which means that the value getting closer to 0 just means it's getting closer to the mean. As we never actually calculated the mean (we just know it's less than the general one, which was taken from a bunch of heavily-fluctuating values anyway), it does not necessarily mean the value is getting smaller; it may just be that the mean for that interval just *happened* to be smaller than the others.

# %% [markdown]
# <br>
#
# ---
# <a/ id='p2'></a>
# [Back to top](#top)
# ## [15 points] Problem 2: Testing and CI Theories; quick problems
#
#
# #### 2A (5 pts):
# Ready the article at the following link: https://tinyurl.com/y6sxe9n8.
#
# (If you have issues, log into the CU-libraries page, and search for the article "The Proposal to Lower P Value Thresholds to .005," by John P. A. Ioannidis from JAMA 2018.)
#
#
# Then summarize it briefly (4-5 sentences), making sure you also answer the following: in what ways are scientists misusing p-values? Do you agree with the suggestion made in this article? What other suggestions are being made to
# use them properly?

# %% [raw]
# Due to the over-reliance of p-values, the author proposes making the default p-value denote significance to be smaller. This is due to people either disregarding studies if they do just barely not pass the p-value threshold, or fabricating data to clear it. Other fields (notably genome studying) have already done this, so it's not that big of a deal to make a general shift. Lowering the threshold, the author figures, will hopefully lead to less cases of incorrect studies being pushed out, or ones that just barely fail to clear the threshold not being marked off entirely.
#
# I agree with this-- in a biology class I took, we had to use p-values, and it usually felt like you did something wrong if your p-value didn't pass the threshold, even if it was just barely, so I can understand why this would be a problem if you were doing an actual study. Editing the value would help, although I'm not certain it's a good panacea for the problem. There's also the idea of p-values suggesting things, with lower numbers being more proof, which I think is more helpful than the first idea on its own.

# %% [markdown]
# #### 2B  (2 pts):
# In general, which is wider: a 95% confidence interval or a 99% confidence interval? How would you explain this to your younger sibling, who is not a statistician?   Use **plain English**.

# %% [raw]
# The bigger the percentage, the bigger the confidence interval. Using the function, we are going to get bigger values if we add and subtract by bigger numbers. Since the Z value get bigger with the perecentage value, we're adding/subtracting larger values to the mean, and thus stretching out the interval.

# %% [markdown]
# #### 2C (2pts):
#
# If you're doing quality control for the average strength of carbon fiber that will be used in airplane construction, and your alternative hypothesis is that the strength of the carbon is below tolerance, and therefore unsafe, would you rather have a low Type I error rate or a low Type II error rate?   **Justify** your answer in complete English sentences.

# %% [raw]
# Since Type I error rates still imply the null hypothesis (that the strength of the carbon fiber is at tolerance in this case) is correct, we would rather that rate be high, and the Type II error (false negative) be low. That way, we can say that our product still works, it's just that sometimes the math doesn't pan out the proper way.

# %% [markdown]
# #### 2D (2pts):
#
# Let $X_1, X_2, \dots X_n$ be independent and identically distributed sample from a normal random variable $N(\mu,1)$.
#
#
# As you've seen, A 95% confidence interval for $\mu$ is $\bar{x} \pm 1.96 \cdot \frac{1}{\sqrt{n}}$.
#
# Let $p$ denote the probability that an *additional* (or new) independent observation falls within this confidence interval. Is $p$ greater than, less than, or equal to 0.95? Justify your answer with both intuition and a formal mathematical statement.

# %%
# Simulation.

def test(mu, n):
    
    # Setup
    
    p = stats.norm.rvs(1)
    # Get mean value
    
    mean = stats.norm.mean(loc = mu, scale = 1)
        
    CI_1 = mean + 1.96 * (1 / np.sqrt(n))
    CI_2 = mean - 1.96 * (1 / np.sqrt(n))
    
    
    lower_CI = "hold"
    upper_CI = "hold"
    
    if CI_1 > CI_2:
        upper_CI = CI_1
        lower_CI = CI_2
    else:
        upper_CI = CI_2
        lower_CI = CI_1
    
    if p > upper_CI or p < lower_CI:
        return False
    else:
        return True
    

success = 0
run_times = 10000
    
for i in range(0, run_times):
    
    if test(0, 200) == True:
        success += 1

print("Out of the " + str(run_times) + " times the code ran, p fell within the confidence interval " + str(success) + " times. That's " + str(success/run_times))
# Out:
# Out of the 10000 times the code ran, p fell within the confidence interval 663 times. That's 0.0663

# %% [raw]
# According to the tests run above, p < 0.95. With how the equation is set up, this makes sense, as p is only a very small part of the confidence interval. Mathematically, we can prove this as well with a difference.

# %% [markdown]
# $\bar{X} = N(0, 1/n)$, and $\bar{Y} = \sqrt{n}$
#
# $$P(\bar{X} - 1.96 * \sqrt{\frac{1}{n}} \leq \bar{Y} \leq \bar{X} + 1.96 * \sqrt{\frac{1}{n}})$$
#
# We subtract $\bar{X}$ from all parts of the inequality.
#
# $$- 1.96 * \sqrt{\frac{1}{n}} \leq \bar{Y} - \bar{X} \leq 1.96 * \sqrt{\frac{1}{n}}$$
#
# As $n$ grows, the upper bound is going to get smaller and less than 0.95, which means that it's very likely that it'll be < 0.95.

# %% [markdown]
# #### 2E (2pts):
# Suppose that 14 people in a sample of 91 are found to be smokers. Calculate the 90% confidence interval
# for the *true* proportion of smokers in the population from which this sample originated. Interpret this interval in a plain English sentence.

# %%
z = 1.645 # Looked this up to double-check

sample_prop = 14/91

CI_plus = sample_prop + z * np.sqrt((1 - sample_prop) / 91)
CI_minus = sample_prop - z * np.sqrt((1 - sample_prop) / 91)

print("The true proportion is (" + str(CI_minus) + ", " + str(CI_plus) + "),meaning that the true proportion falls somewhere in this interval.")
print("(Exclude negative values as we can't have negative people.)")
# Out:
# The true proportion is (-0.004778202387472952, 0.31247051007978066),meaning that the true proportion falls somewhere in this interval.
# (Exclude negative values as we can't have negative people.)

# %% [markdown]
# #### 2F (2pts):
# In an 1881 study Michelson and Newcomb measured the time light took to travel 7400
# meters. Inspecting their study and the descriptions of their 64 measurements, it is reasonable to assume that the data were iid.  Their measurements contained sample statistics in $\mu s$ (or $\frac{sec}{10^6}$) of **mean** $\bar{X}=27.75$ and **standard deviation** of $s = 5.08.$
#
#
# Construct an approximate 95% confidence interval for the time light takes to travel 7400 meters.

# %%
z = 1.960
mean = 27.75
sample_size = 64
std = 5.08

CI_plus = mean + z * (std / np.sqrt(sample_size))
CI_minus = mean - z * (std / np.sqrt(sample_size))

print("Interval: (" + str(CI_minus) + ", " + str(CI_plus) + ")")
# Out:
# Interval: (26.5054, 28.9946)

# %% [markdown]
# ---
#
# <a id='p3'></a>
# [Back to top](#top)
#
# ### [15 points] Problem 3 - Nap time?
#
#
# It is estimated that [about 75% of adults](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4997286/) in the United States drink coffee. Often, coffee is used to replace the need for sleep. It works alright, or so we think. Let's find out, in this exciting homework problem!
#
# [One recent study](https://www.sciencedirect.com/science/article/pii/S1388245703002554) investigated the effects of drinking coffee, taking a nap, and having a ["coffee-nap"](https://lifehacker.com/naps-vs-coffee-which-is-better-when-youre-exhausted-1730643671) - the practice of drinking some coffee *and then* having a short nap. The study broke participants up into three groups of 15 participants each, where the groups would have a nap, or have a coffee, or have a coffee-nap, then perform a task where their reaction time was measured. In previous experiments the mean reaction time measurement was found to be normally distributed. The reaction time means (milliseconds, ms) and standard deviations for the three groups of participants are given in the table below.
#
# $$
# \begin{array}{c|c|c|c}
# \textrm{Group} & \textrm{Sample Size} & \textrm{Mean} & \textrm{Standard Deviation} \\
# \hline
# \textrm{Coffee+Nap} & 15 & 451.3 & 31.9 \\
# \textrm{Coffee} & 15 & 494.2 & 39.6 \\
# \textrm{Nap} & 15 & 492.8 & 45.2 \\
# \end{array}
# $$
#
# **Part A**: Compute a 97.5% t-confidence interval for the mean reaction time measurement for participants in each of these three groups. (You should find three separate confidence intervals.) Report the results.
#
# 1. Can you make any conclusions regarding whether coffee, naps or both (coffee-naps) are better for faster reaction times?
# 2. Why did we use a t-distribution?

# %%
z = 2.241

print("The interval for the coffee+nap is (" + str(451.3 - z * np.sqrt(pow(31.9, 2) / 15)) + ", " + str(451.3 + z * np.sqrt(pow(31.9, 2) / 15)) + ")")
print("The interval for a coffee is (" + str(494.2 - z * np.sqrt(pow(39.6, 2) / 15)) + ", " + str(494.2 + z * np.sqrt(pow(36.9, 2) / 15)) + ")")
print("The interval for a nap is (" + str(492.8 - z * np.sqrt(pow(45.2, 2) / 15)) + ", " + str(492.8 + z * np.sqrt(pow(45.2, 2) / 15)) + ")")
# Out:
# The interval for the coffee+nap is (432.84190358964395, 469.7580964103561)
# The interval for a coffee is (471.2865010078338, 515.551214969973)
# The interval for a nap is (466.64620822106286, 518.9537917789371)

# %% [raw]
# 1. There's some slight overlap of the intervals, though it appears the coffee+nap seems to be the best. However, it's difficult to determine if coffee or a nap is better due to the overlap of the intervals (nap interval spanning over the entire interval for coffee).
#
# 2. The sample size is really small (15), and we need wider intervals as a result.

# %% [markdown]
# **Part B**: Use an appropriate hypothesis test to determine if there sufficient evidence, at the $\alpha = 0.025$ significance level, to conclude that taking a nap promotes faster reaction time than drinking coffee.  Be sure to clearly explain the test that you're doing and state all hypotheses. Do all computations in Python, and report results.

# %%
# Nap better than drinking coffee

# Used: https://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/BS704_HypothesisTest-Means-Proportions/BS704_HypothesisTest-Means-Proportions_print.html
    # Code is my own, this just helps to organize things.

# Use a t-Test because the sample size is small (15)
    # Also, it's gonna be lower-tail test (we assume the nap mean < coffee mean, if it's faster)
    # 28 degrees of freedom
    
cv = -2.048 # From the table

# Reject the null hypothesis (no difference; both equal) if t <= cv
# Other hypothesis:  μ1 < μ2

# Find std for both

std = np.sqrt(((15 - 1) * pow(45.2,2) + (15 - 1) * pow(39.6, 2)) / (15 + 15 - 2))

# Compute t

t = (492.8 - 494.2) / (std * np.sqrt(1/15 + 1/15))


if t <= cv:
    print("t <= cv. We reject the null hypothesis that the both of them are the same.")
else:
    print("t > cv. We do not reject the null hypothesis.")
# Out:
# t > cv. We do not reject the null hypothesis.

# %% [raw]
# There is not sufficient evidence to prove such a thing, as t > the critical value.

# %% [markdown]
# **Part C**: Use an appropriate hypothesis test to determine if there is sufficient evidence, at the $\alpha = 0.025$ significance level, to conclude that taking a coffee-nap promotes faster reaction time than only drinking coffee, or only having a nap.  Be sure to clearly explain the test that you're doing and state all hypotheses. Do all computations in Python, and report results.

# %%
# coffee-nap versus coffee
    # Coffee nap *faster* than drinking coffee

# Copy-pasted code from above
    
cv = -2.048 # From the table

# Reject the null hypothesis (no difference; both equal) if t <= cv
# Other hypothesis:  μ1 < μ2
# μ1 = coffee nap
# μ2 = coffee

# Find std for both

std = np.sqrt(((15 - 1) * pow(31.9,2) + (15 - 1) * pow(45.2, 2)) / (15 + 15 - 2))

# Compute t

t = (451.3 - 494.2) / (std * np.sqrt(1/15 + 1/15))


if t <= cv:
    print("t <= cv. We reject the null hypothesis that the both of them are the same.")
else:
    print("t > cv. We do not reject the null hypothesis.")
# Out:
# t <= cv. We reject the null hypothesis that the both of them are the same.

# %% [raw]
# There is substantial evidence to prove a coffee nap promotes a faster reaction time than coffee.

# %%
# coffee-nap versus nap
    # Coffee nap *faster* than nap

# Copy-pasted code from above
    
cv = -2.048 # From the table

# Reject the null hypothesis (no difference; both equal) if t <= cv
# Other hypothesis:  μ1 < μ2
# μ1 = coffee nap
# μ2 = straight up nap

# Find std for both

std = np.sqrt(((15 - 1) * pow(31.9,2) + (15 - 1) * pow(39.6, 2)) / (15 + 15 - 2))

# Compute t

t = (451.3 - 492.8) / (std * np.sqrt(1/15 + 1/15))


if t <= cv:
    print("t <= cv. We reject the null hypothesis that the both of them are the same.")
else:
    print("t > cv. We do not reject the null hypothesis.")
# Out:
# t <= cv. We reject the null hypothesis that the both of them are the same.

# %% [raw]
# There is substantial evidence to prove a coffee nap promotes a faster reaction time than a nap.

# %% [markdown]
# **Part D**: Generally speaking, we ust $\alpha$ to denote the "probability of error if the null hypothesis is true."  In parts B-C, we performed three hypothesis tests.  Suppost that each of these tests is **independent**, with underlying Probability of type I error of $\alpha=0.025$.  What's the probability that we committed *at least one* Type I error over those 3 tests?  Why might this be important?

# %% [raw]
# The probability of having committed at least one Type I error over the 3 tests is 0.025 + 0.025 + 0.025 = 0.075 chance (7.5%). While the percentage being low is slightly reassuring, this is important as if we *are* wrong and all tests are about the same, then the concept of putting out false information could be a problem, especially considering caffeine is an addictive substance with certain side-effects that not everyone can deal with well.
