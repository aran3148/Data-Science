# %% [markdown]
# # Notebook 22: Multiple Linear Regression
# ***
#
# We'll need Numpy, Matplotlib, Pandas, and scipy.stats for this notebook, so let's load them.

# %%
import numpy as np 
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ### Exercise 1 - Advertising Budgets and Simple Linear Regression
# ***
#
# The data in advertising.csv concerns the sales of a particular product in 200 different markets, along with advertising budgets for each market for three different media types: TV, Radio, and Newspaper.  The sales feature is given in thousands of units, and each of the advertising budget features are given in thousands of dollars.
#
#
# **Part A**: Load the data into a Pandas DataFrame.

# %%
dfAd = pd.read_csv("../Data Science HW/advertising.csv")
dfAd.head()
# Out:
#       tv  radio  news  sales
# 0  230.1   37.8  69.2   22.1
# 1   44.5   39.3  45.1   10.4
# 2   17.2   45.9  69.3    9.3
# 3  151.5   41.3  58.5   18.5
# 4  180.8   10.8  58.4   12.9

# %% [markdown]
# **Part B**: Run the following code to make three separate scatter plots depicting the relationships between each of the features, $\texttt{TV}$, $\texttt{radio}$, and $\texttt{news}$ on the response variable $\texttt{sales}$. From the plots, can you determine whether there appears to be a relationship between each of the advertising media types and the sales of the product?

# %%
media = ["tv", "radio", "news"]

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(8,16))
axes[0].scatter(dfAd["tv"], dfAd["sales"])

for axi, m in enumerate(media): 
    axes[axi].scatter(dfAd[m], dfAd["sales"], color="steelblue")
    axes[axi].grid(alpha=0.25)
    axes[axi].set_xlabel(m, fontsize=16)
    axes[axi].set_ylabel("sales", fontsize=16)

# %%
## ALTERNATIVE!  Pairs plots!
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(dfAd)

# %% [markdown]
# **Part C**: Use [stats.linregress](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.linregress.html) to fit three simple linear regression models to the data of the form
#
# $$
# Y_i = \alpha + \beta x_i + \epsilon_i, \quad \textrm{for } i=1,2, \ldots, n
# $$
#
# where $x$ is a particular media type and  $\epsilon \sim N(0,\sigma^2)$. Interpret your results.

# %%
media = ["tv", "radio", "news"]

for m in media: 
    print("SLR for {} vs sales".format(m))
    print("----------------------")
    bhat, ahat, rval, pval, stderr = stats.linregress(dfAd[m], dfAd["sales"])
    print("intercept = {:.4f}".format(ahat))
    print("slope = {:.4f}".format(bhat))
    print("p-value = {}".format(pval))
    print("\n")
# Out:
# SLR for tv vs sales
# ----------------------
# intercept = 7.0326
# slope = 0.0475
# p-value = 1.4673897001948433e-42
#
#
# SLR for radio vs sales
# ----------------------
# intercept = 9.3116
# slope = 0.2025
# p-value = 4.354966001766976e-19
#
#
# SLR for news vs sales
# ----------------------
# intercept = 12.3514
# slope = 0.0547
# p-value = 0.0011481958688882112

# %% [markdown]
# ### Exercise 2 - Advertising Budgets and Multiple Linear Regression
# ***
#
# In this exercise you'll fit a multiple linear regression model to the advertising data.  For this we'll need a package that we haven't encountered yet called [statsmodels](http://www.statsmodels.org/stable/index.html).  We load it as follows.  Note that you might get a FutureWarning from Pandas.  This is expected.

# %%
import statsmodels.api as sm

# %% [markdown]
# **Part A**: The following code will fit an MLR model to the data. Note that the add_constant function is necessary in order to include an intercept term in the MLR model.

# %%
# Collect the features in a 2D array 
X = dfAd[["tv", "radio", "news"]]

# Add a constant to the array for the intecept 
X = sm.add_constant(X)

# Collect the response data in an array 
y = dfAd["sales"]

# Fit the ordinary least-squares (OLS) model 
model = sm.OLS(y, X).fit()

# %% [markdown]
# The estimated parameters are for the model are stored in model.params.  In this case, because we got $X$ from a Pandas DataFrame, the resulting model parameters are stored in a Pandas Series.

# %%
print(model.params)
# Out:
# const    2.938889
# tv       0.045765
# radio    0.188530
# news    -0.001037
# dtype: float64

# %% [markdown]
# **Part C**: Based on the parameters estimated by the model, replace the unknown $\hat{\beta}_j$ parameters below with the actual values in the model
#
# $$
# \texttt{sales} = 2.94 + 0.046 \times \texttt{TV} + 0.189 \times \texttt{radio} - 0.001 \times \texttt{news}
# $$

# %% [markdown]
# **Part D**: Compare and contrast the model parameters obtained from multiple linear regression with those obtained from the individual simple linear regression models obtained in Exercise 1.  Does something seem fishy?

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):           1.58e-96
# Time:                        08:47:50   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# tv             0.0458      0.001     32.809      0.000       0.043       0.049
# radio          0.1885      0.009     21.893      0.000       0.172       0.206
# news          -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Solution:** The `news` data series is no longer significant, but in the SLR analysis it was. Whaaaaat?!

# %% [markdown]
# **Part E**: We can compute the pair-wise correlation between each of the features directly from the DataFrame using Pandas .corr() function.

# %%
dfAd[["tv", "radio", "news"]].corr()
# Out:
#              tv     radio      news
# tv     1.000000  0.054809  0.056648
# radio  0.054809  1.000000  0.354104
# news   0.056648  0.354104  1.000000

# %% [markdown]
# Does any pair of features seem particularly correlated?  Can you use this to explain the fishiness observed in **Part D**?

# %% [markdown]
# ### Exercise 3 - Polynomial Regression via Multiple Linear Regression
# ***
#
# It's not too difficult to believe that some relationships between features and the response are nonlinear. Consider the following example, where the single feature $x$ and the response $y$ have a quadratic relationship of the form
#
# $$
# Y = \frac{1}{4} - X + X^2 + \epsilon
# $$
#
# The following code samples $n=30$ data points from the true model, fits the SLR model, and plots it against the data. It should be clear from both the picture and the $R^2$-value that the SLR model is a very poor fit of the data.

# %%
# Generate Data
n, sig = 30, 0.05
x = np.linspace(0,1,n) + 0.05*np.random.rand(n) 
y = 0.25 - x + x**2 + stats.norm.rvs(0,sig,size=n)

# Fit SLR model 
bhat, ahat, rval, pval, stderr = stats.linregress(x, y)

# Plot data and SLR model 
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
xplot = np.linspace(np.min(x), np.max(x))
ax.plot(xplot, ahat + bhat*xplot, color="steelblue", lw=3)
ax.scatter(x, y, color="steelblue", s=100, alpha=0.9)
ax.grid(alpha=0.25)
ax.set_xlabel("X", fontsize=16)
ax.set_ylabel("Y", fontsize=16)
ax.text(0.8, np.min(y)+.00, r"$R^2$={:.3f}".format(rval**2), fontsize=20);

# %% [markdown]
# **Part A**: We can fit a **polynomial** model to the single-feature data be thinking of the polynomial features as features in a multiple linear regression model.  If we make the association
#
# $$
# x_1 = x \quad \textrm{and} \quad x_2 = x^2
# $$
#
# then we can fit a multiple linear regression of the form
#
# $$
# \hat{y} = \hat{\beta}_0 + \hat{\beta}_1 x_1 + \hat{\beta}_2 x_2
# $$
#
# Let's see how we can do this in python.

# %%
# Collect the linear feature x and it's square in an array 
X = np.column_stack((x, x**2))

# Add a constant to the array for the intecept 
X = sm.add_constant(X)

# Fit the ordinary least-squares (OLS) model 
polymodel = sm.OLS(y, X).fit()

# Print estimated parameters 
print(polymodel.params)
# Out:
# [ 0.22062556 -0.8016883   0.81291947]

# %% [markdown]
# **Part B**: Write down the estimated MLR model in terms of the features $x_1$ and $x_2$ as well as the interpretation of the associated polynomial model in terms of the single feature $x$. Does this model seem close to the true model that the data was generated from?

# %% [markdown]
# **Solution**: We have
#
# $$
# \hat{y} = 0.2503 - 0.9347 x_1 + 0.9507 x_2 \quad \textrm{and} \quad
# \hat{y} = 0.2503 - 0.9347 x + 0.9507 x^2
# $$
#
# Yes, it seems very close to the true model that the data was generated from.

# %% [markdown]
# **Part C**: Modify the code below to plot the obtained polynomial regression model against the data.  How does it look?

# %%
# Plot data and SLR model 
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
xplot = np.linspace(np.min(x), np.max(x))
# yplot = #TODO 
yplot = polymodel.params[0] + polymodel.params[1]*xplot + polymodel.params[2]*xplot**2
ax.plot(xplot, yplot, color="steelblue", lw=3)
ax.scatter(x, y, color="steelblue", s=100, alpha=0.9)
ax.grid(alpha=0.25)
ax.set_xlabel("X", fontsize=16)
ax.set_ylabel("Y", fontsize=16);

# %% [markdown]
# It looks pretty good!

# %% [markdown]
# **Part D:** Calculate the sum of squared errors, the total sum of squares, and the coefficient of determination for this polynomial regression model. How does the $R^2$ value compare to the linear regression of **Part A**?

# %%
def quadfit(x, params):
    return params[0] + params[1]*x + params[2]*x**2

# still have x and y defined from the initial problem set-up
yhat = quadfit(x, polymodel.params)
ybar = np.mean(y)

# sum of squared errors
sse = np.sum((y-yhat)**2)

# total sum of squares
sst = np.sum((y-ybar)**2)

# coefficient of determination
R2 = 1 - sse/sst

print('SSE = {:0.3f}, SST = {:.3f}, and R^2 = {:.3f}'.format(sse,sst,R2))
# Out:
# SSE = 0.089, SST = 0.231, and R^2 = 0.617

# %% [markdown]
# ### Exercise 4 - Guessing Polynomial Features from Residual Plots
# ***
#
# In the previous exercise we looked for a polynomial regression model that was quadratic because we already knew the true form of the model (which never happens in practice).  If we don't know how many polynomial features to include in our regression model, we can gain insight into which features might be missing by plotting the associated residuals.  Recall that the residual is the difference between the true response value $y$ and the response predicted by the model, $\hat{y}$:
#
# $$
# r_i = y_i - \hat{y}_i
# $$
#
# **Part A**: Suppose that your data really is linear.  What do you expect a scatter plot of the residuals to look like?

# %% [markdown]
# We would expect the residuals to be normally distributed about $0$.

# %% [markdown]
# **Note**: Before continuing, scroll down and execute the cell in the **Helper Functions** section at the bottom of this notebook.
#
# **Part B**: The following code samples data from a true linear model, fits a SLR model to it, and plots the model and the associated residuals.  Does the residual plot agree with what you concluded in **Part A**?

# %%
X, y = nonlinear_data(dataset=0)
fit_and_res_plot(X, y)

X = np.column_stack((X, X**2))
fit_and_res_plot(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.589
# Model:                            OLS   Adj. R-squared:                  0.574
# Method:                 Least Squares   F-statistic:                     40.05
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):           7.59e-07
# Time:                        08:48:51   Log-Likelihood:                 14.604
# No. Observations:                  30   AIC:                            -25.21
# Df Residuals:                      28   BIC:                            -22.41
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8194      0.056     14.516      0.000       0.704       0.935
# x1             0.5924      0.094      6.329      0.000       0.401       0.784
# ==============================================================================
# Omnibus:                        4.131   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                1.599
# Skew:                          -0.016   Prob(JB):                        0.450
# Kurtosis:                       1.869   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 0.819 + 0.592 x^1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     20.33
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):           4.12e-06
# Time:                        08:48:51   Log-Likelihood:                 15.061
# No. Observations:                  30   AIC:                            -24.12
# Df Residuals:                      27   BIC:                            -19.92
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7596      0.087      8.776      0.000       0.582       0.937
# x1             0.9302      0.381      2.440      0.022       0.148       1.712
# x2            -0.3211      0.351     -0.914      0.369      -1.042       0.400
# ==============================================================================
# Omnibus:                        6.909   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                2.021
# Skew:                           0.048   Prob(JB):                        0.364
# Kurtosis:                       1.732   Cond. No.                         22.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 0.760 + 0.930 x^1 + -0.321 x^2

# %% [markdown]
# **Part C**: Now consider a data set that is not linear.  What do you notice about the associated residual plot?

# %%
X, y = nonlinear_data(dataset=1)
fit_and_res_plot(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.030
# Method:                 Least Squares   F-statistic:                    0.1589
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):              0.693
# Time:                        08:50:25   Log-Likelihood:                 32.976
# No. Observations:                  30   AIC:                            -61.95
# Df Residuals:                      28   BIC:                            -59.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1275      0.031      4.166      0.000       0.065       0.190
# x1             0.0202      0.051      0.399      0.693      -0.084       0.124
# ==============================================================================
# Omnibus:                        2.489   Durbin-Watson:                   0.313
# Prob(Omnibus):                  0.288   Jarque-Bera (JB):                1.704
# Skew:                           0.373   Prob(JB):                        0.427
# Kurtosis:                       2.102   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 0.127 + 0.020 x^1

# %% [markdown]
# **Part C**: What polynomial feature do you think is missing?  Complete the following code be adding the missing feature and running the fit again.  What does the residual plot look like now?

# %%
X, y = nonlinear_data(dataset=1)
X = np.column_stack((X, X**2))
fit_and_res_plot(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     89.31
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):           1.25e-12
# Time:                        08:50:30   Log-Likelihood:                 63.344
# No. Observations:                  30   AIC:                            -120.7
# Df Residuals:                      27   BIC:                            -116.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3019      0.017     17.441      0.000       0.266       0.337
# x1            -0.9640      0.076    -12.646      0.000      -1.120      -0.808
# x2             0.9358      0.070     13.322      0.000       0.792       1.080
# ==============================================================================
# Omnibus:                        6.909   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                2.021
# Skew:                           0.048   Prob(JB):                        0.364
# Kurtosis:                       1.732   Cond. No.                         22.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 0.302 + -0.964 x^1 + 0.936 x^2

# %% [markdown]
# **Part C**: OK, one more dataset.  See if you can figure out the missing features and obtain a polynomial regression model that fits the data.

# %%
X, y = nonlinear_data(dataset=2)
fit_and_res_plot(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.115
# Method:                 Least Squares   F-statistic:                     4.767
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):             0.0376
# Time:                        08:51:28   Log-Likelihood:                -50.290
# No. Observations:                  30   AIC:                             104.6
# Df Residuals:                      28   BIC:                             107.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7117      0.491      1.449      0.158      -0.294       1.718
# x1             1.7778      0.814      2.183      0.038       0.110       3.446
# ==============================================================================
# Omnibus:                        1.492   Durbin-Watson:                   0.286
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.298
# Skew:                           0.480   Prob(JB):                        0.523
# Kurtosis:                       2.659   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 0.712 + 1.778 x^1

# %%
X = np.column_stack((X, X**2, X**3))
fit_and_res_plot(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     68.39
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):           1.82e-12
# Time:                        08:51:31   Log-Likelihood:                -19.872
# No. Observations:                  30   AIC:                             47.74
# Df Residuals:                      26   BIC:                             53.35
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5599      0.408     -3.825      0.001      -2.398      -0.722
# x1            31.9238      3.363      9.493      0.000      25.011      38.836
# x2           -78.7877      7.300    -10.792      0.000     -93.794     -63.782
# x3            53.1853      4.498     11.824      0.000      43.940      62.431
# ==============================================================================
# Omnibus:                        0.171   Durbin-Watson:                   1.294
# Prob(Omnibus):                  0.918   Jarque-Bera (JB):                0.111
# Skew:                           0.122   Prob(JB):                        0.946
# Kurtosis:                       2.827   Cond. No.                         125.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = -1.560 + 31.924 x^1 + -78.788 x^2 + 53.185 x^3

# %%
# linear dataset

import random


def fun(x):
    
    return x * 5.56 + 3.4 + random.randint(-3, 10)

x = np.linspace(0, 10, 1000)
y = []

for x_val in x:
    if x_val % 2 == 0:
        y.append(random.randint(-100, 100))
    else:
        y.append(fun(x_val))
        
fit_and_res_plot(x, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                 1.011e+04
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):               0.00
# Time:                        09:01:59   Log-Likelihood:                -3025.9
# No. Observations:                1000   AIC:                             6056.
# Df Residuals:                     998   BIC:                             6066.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.2574      0.316     23.001      0.000       6.638       7.877
# x1             5.4944      0.055    100.563      0.000       5.387       5.602
# ==============================================================================
# Omnibus:                     1288.818   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           585157.763
# Skew:                           6.267   Prob(JB):                         0.00
# Kurtosis:                     120.842   Cond. No.                         11.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 7.257 + 5.494 x^1

# %%
# welcome 2 da playground

x = np.arange(100)

delta = np.random.uniform(-10,10, size=(100,))

y = 5.56 * x + 3.4 + delta

fit_and_res_plot(x, y)

#X = np.column_stack((x, x**2))

#fit_and_res_plot(X, y)

x = np.append(x, 12)
y= np.append(y, 50)

fit_and_res_plot(x, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 7.468e+04
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):          4.59e-143
# Time:                        09:16:31   Log-Likelihood:                -317.99
# No. Observations:                 100   AIC:                             640.0
# Df Residuals:                      98   BIC:                             645.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2424      1.167      2.779      0.007       0.927       5.557
# x1             5.5635      0.020    273.268      0.000       5.523       5.604
# ==============================================================================
# Omnibus:                       29.476   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                5.730
# Skew:                           0.028   Prob(JB):                       0.0570
# Kurtosis:                       1.829   Cond. No.                         114.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 3.242 + 5.563 x^1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 6.900e+04
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):          1.36e-142
# Time:                        09:16:31   Log-Likelihood:                -326.17
# No. Observations:                 101   AIC:                             656.3
# Df Residuals:                      99   BIC:                             661.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6136      1.210      2.160      0.033       0.213       5.014
# x1             5.5722      0.021    262.671      0.000       5.530       5.614
# ==============================================================================
# Omnibus:                        1.802   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.406   Jarque-Bera (JB):                1.667
# Skew:                          -0.207   Prob(JB):                        0.434
# Kurtosis:                       2.526   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Fitted PLR Model: yhat = 2.614 + 5.572 x^1

# %% [markdown]
# <br><br><br><br>
# <br><br><br><br>
# <br><br><br><br>
# <br><br><br><br>
#
# ### Helper Functions
# ***

# %%
import seaborn as sns


def nonlinear_data(dataset, n=30):
    
    if dataset < 0 or dataset > 2: 
        print("Datasets must be numbered 0-2.  Defaulting to 0.")
        dataset = 0
    
    np.random.seed(1237)
    
    X = np.linspace(0,1,n) + .05 * np.random.rand(n)
    
    if dataset == 0: 
        return X, 0.5 + 0.75 * X + .5*np.random.rand(n)
    elif dataset == 1: 
        return X, 0.25 - X + X*X + .1*np.random.rand(n)
    elif dataset == 2: 
        return X, 2*(3*(2*x-1.2)**3 + 2*(2*x-1.2)**2 -(2*x-1.2)) + 1.5*np.random.rand(n)

def fit_and_res_plot(X, y, hint=False):
    
    if len(X.shape)==1:
        x = X
    else:
        x = X[:,0]
    
    # Fit Data 
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    
    print(model.summary())
    
    # Print fitted model 
    print("Fitted PLR Model: yhat = ", end="")
    for p, beta in enumerate(model.params):
        print("{:.3f}".format(beta), end="")
        if p > 0: 
            print(" x^{} ".format(p), end="")
        else:
            print(" ", end="")
        if p != len(model.params)-1:
            print("+ ", end="")
            
    # Plot data/fit 
    yhat = model.predict(X)
    res = y - yhat 
    xp = np.linspace(np.min(x), np.max(x), 50)
    yp = np.zeros(len(xp))
    for p, beta in enumerate(model.params):
        yp += beta * xp**p 
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
    axes[0].scatter(x, y, color="steelblue", s=100, alpha=0.9)
    axes[0].plot(xp, yp, color="steelblue", lw=3)
    axes[0].grid(alpha=0.25)
    axes[0].set_xlabel("X", fontsize=16)
    axes[0].set_ylabel("Y", fontsize=16)
    axes[0].set_title("Data and PLR Fit", fontsize=16)
    
    # Plot residuals 
    axes[1].plot([np.min(x), np.max(x)], [0, 0], lw=2, ls="--", alpha=0.5, color="black")
    axes[1].scatter(x, res, color="#6a9373", s=100, alpha=0.9)
    axes[1].grid(alpha=0.25)
    axes[1].set_xlabel("X", fontsize=16)
    axes[1].set_ylabel("Res", fontsize=16)
    axes[1].set_title("Residual Plot", fontsize=16)
